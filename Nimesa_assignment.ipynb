# %% [markdown]
# <a href="https://colab.research.google.com/github/jaya-nettem/Nimesa_assignment/blob/main/Nimesa_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def get_weather_data(city, api_key):
    url = f"https://samples.openweathermap.org/data/2.5/forecast/hourly?q={city}&appid={api_key}"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        print("Failed to fetch weather data.")
        return None

def get_temperature(data, date_time):
    for item in data['list']:
        if item['dt_txt'] == date_time:
            return item['main']['temp']
    return None

def get_wind_speed(data, date_time):
    for item in data['list']:
        if item['dt_txt'] == date_time:
            return item['wind']['speed']
    return None

def get_pressure(data, date_time):
    for item in data['list']:
        if item['dt_txt'] == date_time:
            return item['main']['pressure']
    return None

def main():
    city = "London,us"
    api_key = "b6907d289e10d714a6e88b30761fae22"

    data = get_weather_data(city, api_key)
    if not data:
        return

    while True:
        print("\nOptions:")
        print("1. Get weather")
        print("2. Get Wind Speed")
        print("3. Get Pressure")
        print("0. Exit")

        choice = input("Enter your choice (0-3): ")

        if choice == "0":
            print("Exiting the program.")
            break
        elif choice == "1":
            date = input("Enter the date (YYYY-MM-DD): ")
            time = input("Enter the time (hh:mm:ss): ")
            date_time = f"{date} {time}"
            temp = get_temperature(data, date_time)
            if temp:
                print(f"Temperature at {date_time}: {temp} K")
            else:
                print("Weather data not found for the specified date and time.")
        elif choice == "2":
            date = input("Enter the date (YYYY-MM-DD): ")
            time = input("Enter the time (hh:mm:ss): ")
            date_time = f"{date} {time}"
            wind_speed = get_wind_speed(data, date_time)
            if wind_speed:
                print(f"Wind Speed at {date_time}: {wind_speed} m/s")
            else:
                print("Weather data not found for the specified date and time.")
        elif choice == "3":
            date = input("Enter the date (YYYY-MM-DD): ")
            time = input("Enter the time (hh:mm:ss): ")
            date_time = f"{date} {time}"
            pressure = get_pressure(data, date_time)
            if pressure:
                print(f"Pressure at {date_time}: {pressure} hPa")
            else:
                print("Weather data not found for the specified date and time.")
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Options:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice (0-3): 1
# Enter the date (YYYY-MM-DD): 2019-03-27
# Enter the time (hh:mm:ss): 18:00:00
# Temperature at 2019-03-27 18:00:00: 278.76 K
#
# Options:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice (0-3): 1
# Enter the date (YYYY-MM-DD): 2019-03-30
# Enter the time (hh:mm:ss): 09:00:00
# Temperature at 2019-03-30 09:00:00: 284.504 K
#
# Options:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice (0-3): 2
# Enter the date (YYYY-MM-DD): 2019-03-30
# Enter the time (hh:mm:ss): 19:00:00
# Wind Speed at 2019-03-30 19:00:00: 0.37 m/s
#
# Options:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice (0-3): 2
# Enter the date (YYYY-MM-DD): 2019-03-31
# Enter the time (hh:mm:ss): 15:00:00
# Wind Speed at 2019-03-31 15:00:00: 5.41 m/s
#
# Options:
# 1. Get weather
# 2. Get Wind Speed
# ...
